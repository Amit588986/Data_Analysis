# %%
from numpy.random import seed
from numpy.random import randint
from numpy import mean
import matplotlib.pyplot as plt

seed(1)
means = [mean(randint(60,90,50)) for _x in range(1000)]
plt.hist(means)
plt.show()
print('the average weight is {} kg'.format(mean(means)))

from scipy.stats import shapiro
stat, p = shapiro(means)
print('statistics =, p = {}'.format(stat,p))
alpha = 0.05
if p>alpha:
    print('sample looks normal (Do not reject null hypothesis)')
else:
    print('sample does not look normal (reject null hypothesis)')
# Out:
# the average weight is 74.54001999999998 kg
# statistics =, p = 0.9982803463935852
# sample looks normal (Do not reject null hypothesis)

# %%
from math import sqrt
from numpy.random import seed   
from numpy.random import randn    
from numpy import mean
from scipy.stats import t
import pandas as pd
from scipy import stats

def dependent_ttest(data1, data2, alpha):
    mean1, mean2 = mean(data1), mean(data2)
    n = len(data1)
    d1 = sum([(data[i]-data2[i])**2 for i in range(n)])
    d2 = sum([(data[i]-data2[i]) for i in range(n)])

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import scipy.stats as st 

x = np.linspace(-5, 5, 5000)
mu = 0
sigma = 1
_pdf = st.norm.pdf(x, mu, sigma)
plt.plot(x, _pdf)

# %%
# for importing data
import panda as pd 
df = pd.read_excel(r'' dtype = {"Student": str, "Marks": float})
print(df)
print("Sum:" df["Marks"].sum())
print("Mean:" df["Marks"].sum())
print(df_anova)
plt.hist()
# Out:
#   File "<ipython-input-10-35f9ed70235f>", line 3
#     df = pd.read_excel(r'D:/DEEPAK KUAMAR = 134334 = VOC IT = A9 1.xlsx' dtype = {"Student": str, "Marks": float})
#                                                                          ^
# SyntaxError: invalid syntax
